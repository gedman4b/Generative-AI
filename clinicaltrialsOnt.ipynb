# %%
from rdflib import Graph
from rdflib.term import Literal
from rdflib.namespace import XSD

g = Graph()
g.parse("ttl/clinicaltrials.ttl")
#g.serialize(destination="ttl/clinicaltrials.jsn", format="json-ld")
# Out:
# <Graph identifier=N8602e544995a46da9317c9c9bcd669f3 (<class 'rdflib.graph.Graph'>)>

# %%
g.triples((None,None,None))
# Out:
# <generator object Graph.triples at 0x0000028C25E7FAC0>

# %%
for s,p,o in g.triples((None,None,None)):
    if o.__class__ != Literal:
        o = o.fragment
    print(s.fragment,p.fragment,o)
# Out:
# hasEndDate label has end date
# Drug comment A substance used to diagnose, treat, or prevent a disease or medical condition.
# hasOutcome label has Outcome
# Phase3 type Class
# hasPrimaryOutcomeMeasure range string
# hasEndDate range date
# Intervention label Intervention
# hasIntervention type ObjectProperty
# hasInterventionName domain Intervention
# hasLocations type DatatypeProperty
# hasPhase range Phase
# hasStudyURL domain ClinicalTrial
# hasIntervention label has Intervention
# hasConditionName label has condition name
# Phase3 subClassOf Phase
# DoubleBlind subClassOf ClinicalTrial
# hasPhase label has Phase
# Role label Role
# hasOtherOutcomeMeasure type DatatypeProperty
# hasStartDate type DatatypeProperty
# hasPhaseName type DatatypeProperty
# hasOutcome comment Relates a clinical trial to the outcome (s) being measured.
# hasInterventionName label has intervention name
# hasPrimaryOutcomeMeasure type DatatypeProperty
# hasEnrollmentNumber type DatatypeProperty
# hasEnrollmentNumber range integer
# Procedure comment A medical technique or course of action performed on a patient.
# hasStudyURL type DatatypeProperty
# Intervention type Class
# Phase type Class
# Role comment An individual's assigned involvement in a clinical trial
# Procedure subClassOf Intervention
# hasOtherOutcomeMeasure domain Outcome
# hasOtherOutcomeMeasure label has other outcome measure
# hasCondition range Condition
# isSponsoredBy comment Relates a clinical trial to the organization (s) sponsoring or funding it.
# hasBriefSummary type DatatypeProperty
# Drug subClassOf Intervention
# Outcome comment A measurable result or effect of a clinical trial.
# hasPhase comment Relates a clinical trial to the phase it belongs to.
# Procedure type Class
# RandomizedControlled type Class
# Condition label Condition
# Phase4 subClassOf Phase
# SingleBlind subClassOf ClinicalTrial
# hasCondition comment Relates a clinical trial to the condition (s) being studied.
# hasParticipant comment Relates a clinical trial to the Patient.
# hasPrimaryOutcomeMeasure label has primary outcome measure
# hasCondition label has Condition
# Organization label Organization
# isSponsoredBy type ObjectProperty
# isSponsoredBy domain ClinicalTrial
# ClinicalTrial type Class
# hasIntervention domain ClinicalTrial
# hasStudyStatus range string
# Device subClassOf Intervention
# ClinicalTrial comment A research study that investigates the safety and effectiveness of medical interventions on human subjects.
# DoubleBlind type Class
# hasParticipant label has Participant
# hasLocations range string
# hasInterventionName type DatatypeProperty
# Phase2 type Class
# Person type Class
# Phase2 comment The second phase of a clinical trial, involving a larger number of participants to assess safety and efficacy.
# Role type Class
# hasStudyType range string
# PlaceboControlled label Placebo-Controlled Trial
# Phase label Phase
# hasStudyStatus label has study status
# hasParticipant range string
# hasPhaseName domain Phase
# hasStudyStatus type DatatypeProperty
# RandomizedControlled label Randomized Controlled Trial
# Device label Device
# Phase comment A stage in the development of a clinical trial, indicating the level of evidence and safety.
# Phase2 label Phase 2
# hasEnrollmentNumber domain Enrollment
# Phase4 label Phase 4
# hasSecondaryOutcomeMeasure label has secondary outcome measure
# hasParticipant label has title
# Device comment A medical instrument, apparatus, machine, or implant used to diagnose, treat, or prevent a disease or medical condition.
# isSponsoredBy range Organization
# Intervention comment A medical treatment, procedure, or device used in a clinical trial.
# Outcome label Outcome
# Phasel type Class
# hasStudyType domain ClinicalTrial
# hasPhaseName label has phase
# hasBriefSummary range string
# Phase3 comment The third phase of a clinical trial, involving a larger population to confirm effectiveness and monitor side effects.
# isSponsoredBy label is Sponsored By
# hasEndDate domain ClinicalTrial
# Enrollment label Enrollment
# hasCompletionDate range string
# Procedure label Procedure
# DoubleBlind label Double-Blind Trial
# Outcome type Class
# Condition comment A disease, disorder, or medical condition being studied in a clinical trial.
# SingleBlind label Single-Blind Trial
# hasParticipant type ObjectProperty
# Phasel label Phase 1
# PlaceboControlled subClassOf ClinicalTrial
# hasOutcome type ObjectProperty
# hasOutcome domain ClinicalTrial
# hasSecondaryOutcomeMeasure range string
# hasEnrollmentNumber label has enrollment number
# Enrollment type Class
# Phasel subClassOf Phase
# Drug type Class
# hasCondition type ObjectProperty
# hasCondition domain ClinicalTrial
# Device type Class
# Phase3 label Phase 3
# hasIntervention range Intervention
# hasCompletionDate type DatatypeProperty
# Phase2 subClassOf Phase
# hasInterventionName range string
# hasStudyType label has study type
# hasPhaseName range string
# hasStudyStatus domain ClinicalTrial
# hasSecondaryOutcomeMeasure type DatatypeProperty
# hasStudyURL range string
# hasLocations domain ClinicalTrial
# Organization comment An entity responsible for conducting or sponsoring a clinical trial.
# Phase4 comment The final phase of a clinical trial, conducted after the intervention is approved, to monitor long-term effects.
# hasOutcome range Outcome
# ClinicalTrial label Clinical Trial
# hasOtherOutcomeMeasure range string
# Enrollment comment Participant in a clinical trial.
# hasSecondaryOutcomeMeasure domain Outcome
# Organization type Class
# hasBriefSummary label has brief summary
# hasConditionName type DatatypeProperty
# hasPhase type ObjectProperty
# hasPhase domain ClinicalTrial
# Drug label Drug
# hasStartDate range date
# hasStudyType type DatatypeProperty
# hasStartDate domain ClinicalTrial
# hasParticipant domain ClinicalTrial
# hasConditionName range string
# Condition type Class
# hasLocations label has locations
# hasStudyURL label has study URL
# Phase subClassOf ClinicalTrial
# hasConditionName domain Condition
# hasEndDate type DatatypeProperty
# hasCompletionDate label has completion date
# hasStartDate label has start date
# SingleBlind type Class
# PlaceboControlled type Class
# hasPrimaryOutcomeMeasure domain Outcome
# hasIntervention comment Relates a clinical trial to the intervention (s) being studied.
# Person label Person
# Person comment An individual involved in a clinical trial, such as a participant, investigator, or sponsor.
# hasBriefSummary domain ClinicalTrial
# Phasel comment The initial phase of a clinical trial, typically involving a small number of healthy volunteers.
# hasCompletionDate domain ClinicalTrial
# RandomizedControlled subClassOf ClinicalTrial
# Phase4 type Class

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create graph
G = nx.DiGraph()
G.add_edges_from((source, target, {'relation': relation}) for source, relation, target in g.triples((None,None,None)))

# Plot the graph
plt.figure(figsize=(8,5), dpi=300)
pos = nx.spring_layout(G, k=3, seed=0)

nx.draw_networkx_nodes(G, pos, node_size=100)
nx.draw_networkx_edges(G, pos, edge_color='red')
nx.draw_networkx_labels(G, pos, font_size=8)
edge_labels = nx.get_edge_attributes(G, 'relation')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=4)

# Display the plot
plt.axis('off')
plt.show()

# %%
answ = "there U"
test = "hello"
answ = test + (answ.replace(" ", "_"))
answ
# Out:
# 'hellothere_U'
